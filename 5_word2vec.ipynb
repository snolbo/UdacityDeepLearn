# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'originated', 'term', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases  = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 30001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.392866
# Nearest to up: cruijff, decompose, spectrometer, fashioning, daniel, withhold, deformations, parthian,
# Nearest to so: donors, nanda, cedilla, numeral, propto, rence, preventing, tzara,
# Nearest to american: rushdie, mauro, looped, immersed, arithmetic, macabre, zef, gecko,
# Nearest to a: teodoro, fragrance, ostara, alec, theology, grok, tabor, varnish,
# Nearest to seven: lindh, meltzer, romance, vous, dubious, differently, wort, conditions,
# Nearest to four: haley, demonstration, leger, chuan, malo, nims, protists, sampler,
# Nearest to they: resulting, pence, mott, voluminous, urraca, asteroid, uncertainty, tumour,
# Nearest to of: reflex, tempore, mock, acids, vertebrates, handling, softened, gigabytes,
# Nearest to was: nihon, interpol, popularized, borrows, hawk, parker, nueva, derbyshire,
# Nearest to more: ion, careless, revoked, totalling, attributing, dutch, oven, ate,
# Nearest to most: launching, jdk, bernardo, karim, timely, collingwood, nominees, gath,
# Nearest to nine: expertise, foundational, seattle, men, illnesses, objected, baserunner, odors,
# Nearest to only: canto, momenta, shirow, denise, democide, ridiculed, philippine, extrinsic,
# Nearest to there: yemen, hydroxybutyrate, fenrir, documentary, copyrighted, prod, tumours, fughetta,
# Nearest to if: longed, civilian, guarani, capitalize, simplicius, ssn, arrival, siliceous,
# Nearest to not: wargame, unproven, sucking, mailboxes, utility, ditka, gymnast, hannah,
# Average loss at step 2000: 4.407888
# Average loss at step 4000: 3.644215
# Average loss at step 6000: 3.746423
# Average loss at step 8000: 3.752609
# Average loss at step 10000: 3.658304
# Nearest to up: daniel, lana, decompose, galician, avtovaz, quantifiers, transition, bardeen,
# Nearest to so: sheryl, tzara, rence, idiopathic, period, numeral, donors, amazonas,
# Nearest to american: mauro, rushdie, looped, zef, muse, kush, care, hpv,
# Nearest to a: the, this, measurable, ahaziah, monochromatic, well, epistles, laozi,
# Nearest to seven: six, nine, four, five, eight, three, two, zero,
# Nearest to four: five, six, eight, three, two, seven, nine, zero,
# Nearest to they: there, he, it, not, we, resulting, bait, tylor,
# Nearest to of: in, for, s, from, asymptotically, or, and, commences,
# Nearest to was: is, were, has, by, had, are, crested, derbyshire,
# Nearest to more: esc, snowfall, valves, nothing, chained, numbers, mithraeum, careless,
# Nearest to most: bernardo, wpa, quake, maximian, timely, jdk, rebounded, collingwood,
# Nearest to nine: eight, six, five, seven, three, four, zero, two,
# Nearest to only: ridiculed, pan, blackpool, stargate, philippine, did, nextel, guang,
# Nearest to there: it, they, he, dos, exercised, usually, asterism, grimoire,
# Nearest to if: civilian, longed, after, chitin, could, when, filings, stretched,
# Nearest to not: also, musik, they, generally, mis, stationery, wargame, nach,
# Average loss at step 12000: 3.643625
# Average loss at step 14000: 3.590805
# Average loss at step 16000: 3.581112
# Average loss at step 18000: 3.489094
# Average loss at step 20000: 3.524271
# Nearest to up: him, lana, doping, daniel, galician, quantifiers, headshot, arkham,
# Nearest to so: inquire, sheryl, observe, romani, danelaw, period, terran, idiopathic,
# Nearest to american: mauro, rushdie, official, kush, muse, care, fireworks, texas,
# Nearest to a: any, the, another, its, amanda, caitlin, this, laozi,
# Nearest to seven: eight, six, four, five, nine, three, one, zero,
# Nearest to four: seven, five, six, eight, three, nine, two, zero,
# Nearest to they: he, we, there, you, not, it, who, acceded,
# Nearest to of: seeker, carlisle, in, oats, gloomy, from, tricyclic, ferris,
# Nearest to was: is, were, had, has, ammi, be, being, been,
# Nearest to more: less, most, esc, very, numbers, askari, zines, empirical,
# Nearest to most: more, bernardo, some, timely, wpa, esc, many, stjepan,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to only: always, blackpool, stargate, ridiculed, pan, philippine, felsic, did,
# Nearest to there: they, it, he, usually, still, exercised, dos, this,
# Nearest to if: when, civilian, filings, after, though, pedagogue, claudian, walt,
# Nearest to not: they, generally, you, often, stitched, musik, receive, still,
# Average loss at step 22000: 3.575825
# Average loss at step 24000: 3.576510
# Average loss at step 26000: 3.555964
# Average loss at step 28000: 3.522614
# Average loss at step 30000: 3.497686
# Nearest to up: him, out, back, doping, transition, lana, deformations, arkham,
# Nearest to so: romani, inquire, terran, returns, danelaw, transgressions, sheryl, taif,
# Nearest to american: kush, british, official, muse, mauro, ncaa, fireworks, including,
# Nearest to a: any, the, schindler, underside, another, little, bridgeport, monochromatic,
# Nearest to seven: five, eight, six, nine, three, four, zero, one,
# Nearest to four: five, eight, six, seven, three, nine, zero, two,
# Nearest to they: we, there, he, you, it, not, she, still,
# Nearest to of: fundamental, for, ruinous, including, corrupting, from, ferris, asymptotically,
# Nearest to was: is, has, had, were, be, been, became, being,
# Nearest to more: less, most, very, esc, faster, collector, quite, snowfall,
# Nearest to most: more, some, many, esc, marketed, membrane, wpa, dreary,
# Nearest to nine: eight, seven, five, six, three, four, zero, one,
# Nearest to only: always, blackpool, pan, disapproval, not, still, ridiculed, usually,
# Nearest to there: they, it, he, still, usually, which, often, she,
# Nearest to if: when, since, could, though, twitch, after, filings, where,
# Nearest to not: they, generally, never, still, nach, also, only, musik,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels


print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])


batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases  = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, bag_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\util\tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.877139
# Nearest to th: tzu, interbreed, micro, expiry, tupolev, tram, iaea, mugabe,
# Nearest to a: prat, unusually, amenities, druidism, detachable, carolyn, inter, wits,
# Nearest to see: ramps, realised, denslow, vil, pinkish, militaristic, reductive, kalamazoo,
# Nearest to many: referenda, foregone, hires, anniversaries, completeness, waff, mediawiki, stringed,
# Nearest to and: eagle, basenji, galactose, brugha, plugs, moritz, cdc, pcp,
# Nearest to be: sierra, negotiator, rodney, eucalyptus, determines, height, incriminating, crete,
# Nearest to who: gliding, microfilm, monochrome, reproductions, tasso, inquired, or, beams,
# Nearest to was: pageant, priests, ahmet, xinjiang, sefirot, kevlar, thither, embezzlement,
# Nearest to in: compartments, squirrels, nutrient, longstanding, clear, capua, w, yardbirds,
# Nearest to more: esr, geologically, typing, goin, administrative, crossing, harvesting, northampton,
# Nearest to not: horribly, crumble, antelope, stirling, bedi, divorces, pyrenees, justifying,
# Nearest to it: santiago, righteousness, underdogs, kuti, hydroponic, missionary, syllables, casualties,
# Nearest to is: baer, inspector, outre, vodafone, esteem, miguel, slipknot, fibrous,
# Nearest to as: fao, quarters, laysan, synchronous, cardboard, portfolios, intergovernmental, pharos,
# Nearest to often: maltese, polishing, highland, harrowing, benthic, strachey, frobisher, opened,
# Nearest to years: franca, comprises, foreshadowed, indulging, horribly, runway, doubled, eyesight,
# Average loss at step 2000: 4.594848
# Average loss at step 4000: 3.932809
# Average loss at step 6000: 3.718132
# Average loss at step 8000: 3.527314
# Average loss at step 10000: 3.464713
# Nearest to th: nd, poetical, missouri, pedagogic, revolted, categorically, daredevil, classmate,
# Nearest to a: the, any, an, this, another, no, egyptologists, biola,
# Nearest to see: jugnauth, flatulence, parsecs, jayne, gpl, piet, lorne, peano,
# Nearest to many: some, several, various, other, these, tariq, all, wessel,
# Nearest to and: or, reuter, while, but, mesoamerica, crocker, however, uart,
# Nearest to be: refer, griffin, tarzan, have, dimaggio, whomever, go, anglicised,
# Nearest to who: he, by, which, vistula, benzoyl, hexagrams, respondents, powerless,
# Nearest to was: is, became, were, evaporates, has, fam, had, are,
# Nearest to in: through, beauharnais, knowledgeable, redstone, on, during, from, receptions,
# Nearest to more: less, most, tougher, rather, sudbury, bags, wrapper, better,
# Nearest to not: krause, hatchback, still, diurnal, harden, bog, ketamine, darboux,
# Nearest to it: he, she, this, clogged, there, ecclesiastics, cycladic, temp,
# Nearest to is: was, became, has, are, does, ordo, exporting, guillotined,
# Nearest to as: hadassah, fao, sabbath, pronouns, lethbridge, christine, felling, skeletal,
# Nearest to often: neville, also, usher, boswell, important, cardoso, interpreted, ttingen,
# Nearest to years: kirov, josiah, constructivists, students, pfa, income, directors, dictum,
# Average loss at step 12000: 3.481591
# Average loss at step 14000: 3.432944
# Average loss at step 16000: 3.426211
# Average loss at step 18000: 3.410524
# Average loss at step 20000: 3.211510
# Nearest to th: nd, st, scooter, seven, gawain, twentieth, missouri, categorically,
# Nearest to a: the, another, every, any, each, an, certifications, this,
# Nearest to see: warp, civ, parsecs, gnumeric, viciously, blackberry, physiologically, testimonies,
# Nearest to many: some, several, various, both, tariq, all, most, numerous,
# Nearest to and: or, but, while, including, peat, s, rag, dict,
# Nearest to be: being, have, refer, anglicised, remain, griffin, go, produce,
# Nearest to who: benzoyl, which, cornered, he, whom, adv, tarski, jvm,
# Nearest to was: is, became, were, are, had, communally, being, has,
# Nearest to in: since, within, during, of, smuts, on, through, until,
# Nearest to more: less, most, very, greater, rather, better, other, icon,
# Nearest to not: still, so, cameraman, krause, minimalist, somewhat, norsemen, what,
# Nearest to it: she, he, this, there, they, nimitz, ecclesiastics, laurens,
# Nearest to is: was, are, became, has, were, pleaded, includes, sunspots,
# Nearest to as: fao, collated, impede, wendell, knowledgeable, longsword, cacao, sailplane,
# Nearest to often: generally, sometimes, usually, commonly, still, also, rooks, frequently,
# Nearest to years: months, days, year, kirov, joseon, centuries, constructivists, reputation,
# Average loss at step 22000: 3.359384
# Average loss at step 24000: 3.298057
# Average loss at step 26000: 3.252830
# Average loss at step 28000: 3.290830
# Average loss at step 30000: 3.226201
# Nearest to th: nd, nine, gawain, st, revolted, twentieth, between, b,
# Nearest to a: another, any, the, every, biola, federer, an, amounts,
# Nearest to see: but, known, called, viciously, zanetti, baha, bandai, testimonies,
# Nearest to many: some, several, various, both, most, all, such, these,
# Nearest to and: while, or, but, including, although, repainted, like, than,
# Nearest to be: remain, refer, being, lead, been, become, anglicised, go,
# Nearest to who: which, that, benzoyl, he, young, tarski, by, sunga,
# Nearest to was: is, became, were, had, are, being, has, evaporates,
# Nearest to in: during, within, since, from, on, redstone, yzerman, until,
# Nearest to more: less, rather, better, greater, very, larger, most, parliamentarians,
# Nearest to not: still, krause, never, now, you, hoppers, bog, ryder,
# Nearest to it: he, she, this, pooh, there, what, still, bile,
# Nearest to is: was, are, became, has, remains, means, evaporates, dehydrated,
# Nearest to as: hadassah, fao, mithra, galactose, binet, shanahan, collier, homotopy,
# Nearest to often: sometimes, commonly, generally, frequently, widely, still, also, usually,
# Nearest to years: days, months, year, decades, centuries, weeks, constructivists, minutes,
# Average loss at step 32000: 3.012879
# Average loss at step 34000: 3.199968
# Average loss at step 36000: 3.189976
# Average loss at step 38000: 3.163332
# Average loss at step 40000: 3.155122
# Nearest to th: nd, twentieth, gawain, fifth, st, nine, third, phenotypes,
# Nearest to a: another, the, any, every, an, kerr, each, jarmusch,
# Nearest to see: includes, liquidated, but, known, contains, allow, viciously, deoxyribonucleic,
# Nearest to many: some, several, various, numerous, most, both, all, these,
# Nearest to and: while, or, including, but, cfc, than, although, which,
# Nearest to be: being, lead, remain, refer, represent, produce, become, been,
# Nearest to who: benzoyl, tarski, sunga, edmond, actually, empower, he, whom,
# Nearest to was: is, became, were, being, are, has, had, remains,
# Nearest to in: within, during, since, on, throughout, until, beauharnais, redstone,
# Nearest to more: less, rather, very, better, greater, most, fewer, larger,
# Nearest to not: now, still, krause, somewhat, never, sclerosis, deemed, vargas,
# Nearest to it: he, she, this, pooh, replicas, now, still, moller,
# Nearest to is: was, are, became, has, includes, were, remains, refers,
# Nearest to as: retrograde, hadassah, realisation, childless, before, liqueur, bicarbonate, inquisitorial,
# Nearest to often: sometimes, commonly, usually, generally, frequently, still, widely, now,
# Nearest to years: days, months, decades, year, weeks, minutes, centuries, times,
# Average loss at step 42000: 3.197530
# Average loss at step 44000: 3.140958
# Average loss at step 46000: 3.137386
# Average loss at step 48000: 3.058772
# Average loss at step 50000: 3.064568
# Nearest to th: nd, twentieth, nine, fifth, st, third, gawain, nineteenth,
# Nearest to a: another, the, any, egyptologists, amounts, every, biola, chrismation,
# Nearest to see: includes, viciously, genevieve, called, cante, deoxyribonucleic, warp, baud,
# Nearest to many: some, several, various, numerous, multiple, all, most, these,
# Nearest to and: or, while, including, but, cfc, mesoamerica, dominatrices, although,
# Nearest to be: being, lead, remain, refer, produce, mean, represent, become,
# Nearest to who: benzoyl, edmond, sunga, that, he, which, yom, chs,
# Nearest to was: is, were, became, are, being, had, remains, appears,
# Nearest to in: during, within, from, throughout, until, into, on, redstone,
# Nearest to more: less, rather, greater, very, larger, better, fewer, too,
# Nearest to not: krause, still, now, never, somewhat, nothing, abrahamic, mismatch,
# Nearest to it: he, she, this, there, leonov, scar, cycladic, interacted,
# Nearest to is: was, are, became, remains, has, were, includes, makes,
# Nearest to as: realisation, mno, fao, producing, lethbridge, duchess, collated, tensor,
# Nearest to often: usually, commonly, sometimes, frequently, generally, still, widely, typically,
# Nearest to years: days, decades, months, weeks, minutes, hours, centuries, year,
# Average loss at step 52000: 3.088665
# Average loss at step 54000: 3.089817
# Average loss at step 56000: 2.920123
# Average loss at step 58000: 3.026842
# Average loss at step 60000: 3.049173
# Nearest to th: nd, twentieth, st, third, nine, nineteenth, fifth, gawain,
# Nearest to a: another, the, any, every, no, an, ursinus, enough,
# Nearest to see: includes, include, weinberg, civ, keyboards, viciously, contain, deoxyribonucleic,
# Nearest to many: some, several, various, numerous, all, these, certain, multiple,
# Nearest to and: while, but, although, or, including, though, however, hotline,
# Nearest to be: remain, being, lead, have, refer, cause, occur, exist,
# Nearest to who: benzoyl, he, whose, obstacle, dryden, already, which, whom,
# Nearest to was: is, became, were, had, becomes, are, remains, remained,
# Nearest to in: within, during, throughout, beauharnais, kano, redstone, since, at,
# Nearest to more: less, rather, very, greater, larger, most, highly, smaller,
# Nearest to not: krause, never, still, nothing, mingle, now, abrahamic, mismatch,
# Nearest to it: she, he, this, still, there, temp, scar, largely,
# Nearest to is: was, are, has, includes, became, exists, contains, becomes,
# Nearest to as: collated, demonym, tensor, sprague, hadassah, impede, mno, swaim,
# Nearest to often: commonly, frequently, sometimes, usually, generally, widely, still, typically,
# Nearest to years: days, decades, months, weeks, hours, minutes, centuries, year,
# Average loss at step 62000: 3.011466
# Average loss at step 64000: 2.923933
# Average loss at step 66000: 2.930143
# Average loss at step 68000: 2.974189
# Average loss at step 70000: 3.008916
# Nearest to th: nd, st, nine, twentieth, third, nineteenth, fifth, assassinating,
# Nearest to a: another, the, any, every, certifications, this, enough, biola,
# Nearest to see: includes, civ, viciously, provides, include, known, including, make,
# Nearest to many: several, some, various, numerous, all, thousands, these, those,
# Nearest to and: or, but, cfc, while, including, although, repainted, organising,
# Nearest to be: remain, lead, being, refer, mean, cause, been, become,
# Nearest to who: he, benzoyl, which, whose, corinth, interracial, abrahams, beatrix,
# Nearest to was: is, were, became, becomes, are, has, remains, remained,
# Nearest to in: during, throughout, within, since, through, redstone, outside, on,
# Nearest to more: less, rather, greater, larger, very, fewer, highly, most,
# Nearest to not: still, never, now, nothing, krause, almost, mismatch, nor,
# Nearest to it: he, she, scar, quite, temp, this, ugo, auburn,
# Nearest to is: was, are, makes, remains, became, becomes, includes, exists,
# Nearest to as: like, hadassah, realisation, budo, pascha, operettas, booty, collated,
# Nearest to often: sometimes, commonly, frequently, usually, generally, now, typically, widely,
# Nearest to years: days, months, decades, minutes, year, weeks, hours, centuries,
# Average loss at step 72000: 2.946288
# Average loss at step 74000: 2.863967
# Average loss at step 76000: 3.000714
# Average loss at step 78000: 3.000609
# Average loss at step 80000: 2.841726
# Nearest to th: st, nd, third, twentieth, nine, nineteenth, fourth, fifth,
# Nearest to a: another, any, the, every, each, this, mdf, zapotec,
# Nearest to see: provides, called, includes, saw, viciously, but, holds, civ,
# Nearest to many: some, several, various, numerous, all, multiple, thousands, most,
# Nearest to and: or, including, though, repainted, but, while, etc, like,
# Nearest to be: remain, being, refer, occur, represent, provide, lead, create,
# Nearest to who: benzoyl, whom, which, actually, fins, placeholder, whose, luna,
# Nearest to was: is, were, becomes, became, had, are, has, includes,
# Nearest to in: within, throughout, during, until, on, since, through, including,
# Nearest to more: less, rather, very, greater, most, extremely, better, too,
# Nearest to not: nothing, now, almost, krause, never, still, nigeria, jima,
# Nearest to it: he, she, this, there, quirk, today, itself, cycladic,
# Nearest to is: was, makes, are, becomes, includes, contains, became, exists,
# Nearest to as: collated, impede, mno, homotopy, radiating, hadassah, retrograde, fao,
# Nearest to often: sometimes, frequently, usually, commonly, generally, typically, widely, rarely,
# Nearest to years: months, days, decades, minutes, weeks, year, hours, percent,
# Average loss at step 82000: 2.932284
# Average loss at step 84000: 2.901665
# Average loss at step 86000: 2.920848
# Average loss at step 88000: 2.942794
# Average loss at step 90000: 2.824567
# Nearest to th: nd, st, twentieth, nineteenth, nine, fourth, third, gawain,
# Nearest to a: another, the, any, bai, this, every, its, fictionalised,
# Nearest to see: includes, provides, but, cyclopedia, saw, civ, gnumeric, catalogues,
# Nearest to many: some, several, numerous, various, both, tariq, most, multiple,
# Nearest to and: or, while, including, etc, but, cfc, vesta, visceral,
# Nearest to be: being, remain, lead, occur, refer, represent, been, serve,
# Nearest to who: whom, always, which, benzoyl, actually, young, fo, ethelred,
# Nearest to was: is, were, became, becomes, are, had, has, deter,
# Nearest to in: within, during, throughout, since, on, outside, among, of,
# Nearest to more: less, rather, very, greater, too, highly, quite, fairly,
# Nearest to not: never, nothing, indeed, still, almost, now, moulded, essentially,
# Nearest to it: he, she, this, there, quirk, they, temp, contractors,
# Nearest to is: was, are, becomes, became, makes, provides, remains, includes,
# Nearest to as: collated, longsword, radiating, cacao, budo, impede, swaim, artifact,
# Nearest to often: frequently, sometimes, usually, generally, commonly, typically, actually, rarely,
# Nearest to years: decades, days, months, minutes, weeks, year, hours, centuries,
# Average loss at step 92000: 2.896424
# Average loss at step 94000: 2.879697
# Average loss at step 96000: 2.715746
# Average loss at step 98000: 2.451951
# Average loss at step 100000: 2.709527
# Nearest to th: nd, twentieth, fourth, st, nineteenth, rd, fifth, third,
# Nearest to a: another, the, biola, bai, something, spectacled, any, ursinus,
# Nearest to see: sculptured, includes, saw, refer, include, weinberg, called, allow,
# Nearest to many: some, several, various, numerous, these, multiple, thousands, all,
# Nearest to and: or, but, while, including, however, though, although, like,
# Nearest to be: remain, being, occur, lead, exist, have, refer, become,
# Nearest to who: whom, benzoyl, whose, unmik, actually, beacon, which, he,
# Nearest to was: is, became, were, remained, had, evaporates, are, remains,
# Nearest to in: within, outside, throughout, during, into, on, near, since,
# Nearest to more: less, rather, fewer, greater, most, better, larger, very,
# Nearest to not: never, nothing, indeed, still, now, krause, almost, retroflex,
# Nearest to it: she, he, there, quirk, still, temp, itself, they,
# Nearest to is: was, are, makes, has, includes, contains, exists, remains,
# Nearest to as: mno, realisation, fao, collated, impede, undesired, handedness, wehrmacht,
# Nearest to often: frequently, sometimes, usually, commonly, generally, typically, actually, also,
# Nearest to years: decades, months, minutes, year, days, hours, weeks, centuries,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points + 1, :])


def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()


words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)
